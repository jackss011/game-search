# %%
from urllib import parse as url
from bs4 import BeautifulSoup
import pandas as pd
import requests
import functools

from urllib.request import Request, urlopen

# %%
def steam_search_games(term):
  search_url = 'https://store.steampowered.com/search/?term=' + url.quote(term.strip()) + '&ignore_preferences=1'
  page = requests.get(search_url)

  soup = BeautifulSoup(page.text)
  games_list = soup.find_all(id='search_resultsRows')[0]

  results = []
  
  for row_link in games_list.find_all('a'):
    app_id = row_link.get('data-ds-appid')
    name = row_link.find_all(class_='title')[0].string
    results.append(dict(app_id=app_id, name=name))

  return results

# %%
print(steam_search_games('neon abyss'))
# Out:
# [{'app_id': '788100', 'name': 'Neon Abyss'}, {'app_id': '1518790', 'name': 'Neon Abyss - Alter Ego'}, {'app_id': '1262000', 'name': 'Neon Abyss - Lovable Rogues Pack'}, {'app_id': '1396440', 'name': 'Neon Abyss Soundtrack'}, {'app_id': None, 'name': 'Neon Abyss Deluxe Edition'}, {'app_id': '1182150', 'name': 'Neon Abyss Demo'}, {'app_id': None, 'name': 'The Neon Cloud Runner Bundle'}, {'app_id': None, 'name': 'Tesla Ultimate Bundle'}, {'app_id': '1048350', 'name': 'Nigate Tale'}, {'app_id': None, 'name': '10tons Total'}, {'app_id': None, 'name': 'Roguelike Bundle'}, {'app_id': '1276781', 'name': 'Tidal Shock: DIVE CREW DLC'}, {'app_id': '1276780', 'name': 'Tidal Shock: SURFERS DLC'}, {'app_id': '847810', 'name': 'Endless Horizon'}, {'app_id': '873720', 'name': 'Pac Adventures 3D'}]

# %%
def steam_db_price_history(app_id):
  price_url = 'https://steamdb.info/api/GetPriceHistory/?appid=' + str(app_id).strip() + '&cc=eu'

  headers={
    'accept-language': 'en-US;q=0.9,en;q=0.8',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    'accept-encoding': 'gzip, deflate, br',
    # ':authority': 'steamdb.info',
    # ':method': 'GET',
    # ':path': f'/api/GetPriceHistory/?appid={app_id}&cc=eu',
    # ':scheme': 'https',
    'referer': f'https://steamdb.info/app/{app_id}/',
  }

  prices_res = requests.get(price_url, headers=headers, timeout=30)
  prices_json = prices_res.json()
  
  history = prices_json['data']['history']
  price_history = [ dict(time=h['x'], price=h['y'], discount=h['d'] / 100) for h in history ]
  
  return price_history

# %%
def steam_db_discount_data(price_history):
    discount_history = [ datapoint for datapoint in price_history if datapoint['price'] > 0 and datapoint['discount'] > 0 ]

    if len(discount_history) > 0:
        latest = discount_history[len(discount_history) - 1]

        biggest = functools.reduce(lambda a, b: a if a['discount'] > b['discount'] else b, discount_history)

        same = (latest['time'] == biggest['time'])

        return dict(latest=latest, biggest=biggest, same=same)
    else:
        return None

# %%
def ig_search_games(term):
  region = ''
  query = url.quote(term.strip())
  currency = 'EUR'

  search_url = 'https://www.instant-gaming.com/en/search/?' \
    + f'all_types=1&all_cats=1&min_price=0&max_price=100&noprice=1&min_discount=0&max_discount=100&min_reviewsavg=10&max_reviewsavg=100&currency={currency}' \
    + f'&noreviews=1&available_in={region}&gametype=all&sort_by=&query={query}'

  headers = {
    'accept-language': 'en;q=0.8',
    'user-agent': 'Python/3.x requests/1.x',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
  }

  page = requests.get(search_url, headers=headers)
  soup = BeautifulSoup(page.text)

  games_list = soup.find_all('div', class_='item')
  results = []

  for item in games_list:
    name = item.find('div', class_='name').string
    price = item.get('data-price')

    discount_item = item.find('div', class_='discount')
    discount_string = discount_item.string if discount_item is not None else None
    discount = float(discount_string.replace('%', '').replace('-', '')) / 100 if discount_string is not None else None

    platform_badge_classes = item.find('div', class_='badge').get('class')
    platform = platform_badge_classes[1] if len(platform_badge_classes) >= 2 else 'unknown'

    dlc = True if str(item.get('data-dlc')) == '1' else False
    link = item.find('a', class_='cover').get('href')

    results.append(dict(name=name, price=price, discount=discount, platform=platform, dlc=dlc, link=link))

  return results
  # return pd.DataFrame(results, columns=['name', 'price', 'discount', 'platform', 'dlc', 'link'])

# %%
def steam_user_wishlist(vanity_url):
    done = False
    page = 0
    result_list = []

    def extract_data(data):
        sub = data['subs'][0] if len(data['subs']) > 0 else None
        early_access = data.get('early_access')
        prerelease = data.get('prerelease')

        return dict(
            name=data['name'],
            priority=data['priority'],
            price=sub['price'] / 100 if sub else None,
            discount=sub['discount_pct'] / 100 if sub else None,
            early_access=True if early_access is not None and early_access > 0 else False,
            prerelease=True if prerelease is not None and prerelease > 0 else False,
        )

    while not done:
        url = f'https://store.steampowered.com/wishlist/id/{vanity_url}/wishlistdata/?p={page}'
        parsed_json = requests.get(url).json()

        if len(parsed_json) > 0:
            result_list += [ dict(app_id=app_id, **extract_data(data)) for app_id, data in parsed_json.items() ]
            page += 1
        else:
            done = True

    result_list.sort(key=lambda x: int(x['priority']))
    # return pd.DataFrame(result_list)
    return result_list

# %%
def enhanced_wishlist_data(vanity_url, num=10):
    wishlist = steam_user_wishlist(vanity_url)[:num]
    enhanced_wishlist = []

    for wishlist_item in wishlist:
        ig_results = ig_search_games(wishlist_item['name'])
        ig_best = ig_results[0] if len(ig_results) > 0 else None
        ig_data = dict(search_results=ig_results, best_result=ig_best)

        price_history = steam_db_price_history(wishlist_item['app_id'])
        sales_data = steam_db_discount_data(price_history)

        row = dict(**wishlist_item, price_history=price_history, ig_data=ig_data, sales_data=sales_data)
        enhanced_wishlist.append(row)

    return enhanced_wishlist

# %%
# steam_search_games('prey')
# [ x for x in ig_search_games('fallout 4') if not x['dlc'] ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-35ca5b1df442> in <module>
#       1 # steam_search_games('prey')
#       2 # [ x for x in ig_search_games('fallout 4') if not x['dlc'] ]
# ----> 3 steam_db_discount_data(480490)
#
# <ipython-input-37-815b9caa5ead> in steam_db_discount_data(price_history)
#       1 def steam_db_discount_data(price_history):
# ----> 2     discount_history = [ datapoint for datapoint in price_history if datapoint['price'] > 0 and datapoint['discount'] > 0 ]
#       3
#       4     if len(discount_history) > 0:
#       5         latest = discount_history[len(discount_history) - 1]
#
# TypeError: 'int' object is not iterable

# %%
ew = enhanced_wishlist_data('jackss14')

# %%
ew
# Out:
# [{'app_id': '526870',
#   'name': 'Satisfactory',
#   'priority': 1,
#   'price': 29.99,
#   'discount': 0.0,
#   'early_access': True,
#   'prerelease': False,
#   'price_history': [{'time': 1591636144000, 'price': 26.99, 'discount': 0.1},
#    {'time': 1594316604000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1600968684000, 'price': 23.99, 'discount': 0.2},
#    {'time': 1601313660000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1603991003000, 'price': 23.99, 'discount': 0.2},
#    {'time': 1604345100000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1606327649000, 'price': 23.99, 'discount': 0.2},
#    {'time': 1607105190000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1608660844000, 'price': 23.99, 'discount': 0.2},
#    {'time': 1609875725000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1613066850000, 'price': 23.99, 'discount': 0.2},
#    {'time': 1613417192000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1618334147000, 'price': 23.99, 'discount': 0.2},
#    {'time': 1618765805000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1622135573000, 'price': 23.99, 'discount': 0.2},
#    {'time': 1622481255000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1624561416000, 'price': 23.99, 'discount': 0.2},
#    {'time': 1625765685000, 'price': 29.99, 'discount': 0.0}],
#   'ig_data': {'search_results': [{'name': 'Satisfactory',
#      'price': '26.99',
#      'discount': 0.1,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/4229-buy-game-steam-satisfactory/'}],
#    'best_result': {'name': 'Satisfactory',
#     'price': '26.99',
#     'discount': 0.1,
#     'platform': 'steam',
#     'dlc': False,
#     'link': 'https://www.instant-gaming.com/en/4229-buy-game-steam-satisfactory/'}},
#   'sales_data': {'latest': {'time': 1624561416000,
#     'price': 23.99,
#     'discount': 0.2},
#    'biggest': {'time': 1624561416000, 'price': 23.99, 'discount': 0.2},
#    'same': True}},
#  {'app_id': '1174180',
#   'name': 'Red Dead Redemption 2',
#   'priority': 2,
#   'price': 59.99,
#   'discount': 0.0,
#   'early_access': False,
#   'prerelease': False,
#   'price_history': [{'time': 1575480605000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1576173930000, 'price': 47.99, 'discount': 0.2},
#    {'time': 1576347151000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1576779057000, 'price': 47.99, 'discount': 0.2},
#    {'time': 1577988701000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1579802963000, 'price': 47.99, 'discount': 0.2},
#    {'time': 1581013260000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1584468009000, 'price': 47.99, 'discount': 0.2},
#    {'time': 1585073409000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1589217018000, 'price': 47.99, 'discount': 0.2},
#    {'time': 1590426830000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1593104725000, 'price': 47.99, 'discount': 0.2},
#    {'time': 1594315218000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1596128758000, 'price': 47.99, 'discount': 0.2},
#    {'time': 1597338501000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1600886707000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1602094206000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1603990889000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1604343991000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1606327516000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1606850118000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1607536873000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1607970505000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1608660794000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1609875252000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1610734079000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1611943698000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1613066925000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1613414408000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1616087169000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1617297281000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1618852522000, 'price': 0, 'discount': 0.0},
#    {'time': 1618852711000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1621272203000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1622481854000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1624556233000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1625769389000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1626368764000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1627578547000, 'price': 59.99, 'discount': 0.0}],
#   'ig_data': {'search_results': [{'name': 'Red Dead Redemption 2 Standard Edition',
#      'price': '33.49',
#      'discount': 0.44,
#      'platform': 'rockstar',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/5679-buy-game-rockstar-red-dead-redemption-2-standard-edition/'},
#     {'name': 'Red Dead Redemption 2: Ultimate Edition',
#      'price': '43.99',
#      'discount': 0.51,
#      'platform': 'rockstar',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/5653-buy-game-rockstar-red-dead-redemption-2-ultimate-edition/'},
#     {'name': 'Red Dead Redemption 2: Ultimate Edition Xbox ONE',
#      'price': '35.99',
#      'discount': 0.64,
#      'platform': 'xbox-one',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/3233-buy-red-dead-redemption-2-ultimate-edition-xbox-one/'},
#     {'name': 'Red Dead Redemption 2 Xbox ONE',
#      'price': '51.99',
#      'discount': 0.26,
#      'platform': 'xbox-one',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/1744-buy-red-dead-redemption-2-xbox-one/'},
#     {'name': 'Red Dead Redemption 2: Special Edition Xbox ONE',
#      'price': '34.99',
#      'discount': 0.59,
#      'platform': 'xbox-one',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/3207-buy-red-dead-redemption-2-special-edition-xbox-one/'},
#     {'name': 'Red Dead Redemption 2 Special Edition',
#      'price': '38.99',
#      'discount': 0.48,
#      'platform': 'rockstar',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/2584-buy-game-rockstar-red-dead-redemption-2-special-edition/'}],
#    'best_result': {'name': 'Red Dead Redemption 2 Standard Edition',
#     'price': '33.49',
#     'discount': 0.44,
#     'platform': 'rockstar',
#     'dlc': False,
#     'link': 'https://www.instant-gaming.com/en/5679-buy-game-rockstar-red-dead-redemption-2-standard-edition/'}},
#   'sales_data': {'latest': {'time': 1626368764000,
#     'price': 40.19,
#     'discount': 0.33},
#    'biggest': {'time': 1626368764000, 'price': 40.19, 'discount': 0.33},
#    'same': True}},
#  {'app_id': '1190460',
#   'name': 'DEATH STRANDING',
#   'priority': 3,
#   'price': 59.99,
#   'discount': 0.0,
#   'early_access': False,
#   'prerelease': False,
#   'price_history': [{'time': 1573231206000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1599152957000, 'price': 44.99, 'discount': 0.25},
#    {'time': 1599584883000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1603990886000, 'price': 41.99, 'discount': 0.3},
#    {'time': 1604345861000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1606327514000, 'price': 29.99, 'discount': 0.5},
#    {'time': 1606849211000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1607536874000, 'price': 29.99, 'discount': 0.5},
#    {'time': 1607970723000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1608142015000, 'price': 29.99, 'discount': 0.5},
#    {'time': 1609871606000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1613066728000, 'price': 35.99, 'discount': 0.4},
#    {'time': 1613414743000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1616693148000, 'price': 29.99, 'discount': 0.5},
#    {'time': 1617039939000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1619197583000, 'price': 23.99, 'discount': 0.6},
#    {'time': 1620321113000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1622136062000, 'price': 29.99, 'discount': 0.5},
#    {'time': 1622481628000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1623171997000, 'price': 29.99, 'discount': 0.5},
#    {'time': 1623776806000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1624562001000, 'price': 23.99, 'discount': 0.6},
#    {'time': 1625766711000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1626196047000, 'price': 23.99, 'discount': 0.6},
#    {'time': 1626455369000, 'price': 59.99, 'discount': 0.0}],
#   'ig_data': {'search_results': [{'name': 'Death Stranding',
#      'price': '19.99',
#      'discount': 0.67,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/5721-buy-game-steam-death-stranding/'},
#     {'name': 'Warhammer 40.000: Space Wolf',
#      'price': '1.83',
#      'discount': 0.9,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/1937-buy-game-steam-warhammer-40000-space-wolf/'}],
#    'best_result': {'name': 'Death Stranding',
#     'price': '19.99',
#     'discount': 0.67,
#     'platform': 'steam',
#     'dlc': False,
#     'link': 'https://www.instant-gaming.com/en/5721-buy-game-steam-death-stranding/'}},
#   'sales_data': {'latest': {'time': 1626196047000,
#     'price': 23.99,
#     'discount': 0.6},
#    'biggest': {'time': 1626196047000, 'price': 23.99, 'discount': 0.6},
#    'same': True}},
#  {'app_id': '860510',
#   'name': 'Little Nightmares II',
#   'priority': 4,
#   'price': 29.99,
#   'discount': 0.0,
#   'early_access': False,
#   'prerelease': False,
#   'price_history': [{'time': 1607530205000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1622740461000, 'price': 23.99, 'discount': 0.2},
#    {'time': 1623085780000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1624051394000, 'price': 23.99, 'discount': 0.2},
#    {'time': 1625764593000, 'price': 29.99, 'discount': 0.0}],
#   'ig_data': {'search_results': [{'name': 'Little Nightmares II',
#      'price': '20.99',
#      'discount': 0.3,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/5381-buy-game-steam-little-nightmares-ii/'},
#     {'name': 'Little Nightmares II Deluxe Edition',
#      'price': '29.49',
#      'discount': 0.26,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/8085-buy-game-steam-little-nightmares-ii-deluxe-edition/'},
#     {'name': 'Little Nightmares II Xbox ONE / Xbox Series X|S',
#      'price': '27.99',
#      'discount': 0.07,
#      'platform': 'xbox',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/8101-buy-little-nightmares-ii-xbox-one-xbox-series-xs/'}],
#    'best_result': {'name': 'Little Nightmares II',
#     'price': '20.99',
#     'discount': 0.3,
#     'platform': 'steam',
#     'dlc': False,
#     'link': 'https://www.instant-gaming.com/en/5381-buy-game-steam-little-nightmares-ii/'}},
#   'sales_data': {'latest': {'time': 1624051394000,
#     'price': 23.99,
#     'discount': 0.2},
#    'biggest': {'time': 1624051394000, 'price': 23.99, 'discount': 0.2},
#    'same': True}},
#  {'app_id': '775500',
#   'name': 'SCARLET NEXUS',
#   'priority': 5,
#   'price': 49.99,
#   'discount': 0.0,
#   'early_access': False,
#   'prerelease': False,
#   'price_history': [{'time': 1616109004000, 'price': 49.99, 'discount': 0.0},
#    {'time': 1624572005000, 'price': 64.99, 'discount': 0.0},
#    {'time': 1624572304000, 'price': 49.99, 'discount': 0.0}],
#   'ig_data': {'search_results': [{'name': 'Scarlet Nexus',
#      'price': '32.69',
#      'discount': 0.35,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/6906-buy-game-steam-scarlet-nexus/'},
#     {'name': 'Scarlet Nexus Deluxe',
#      'price': '44.89',
#      'discount': 0.31,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/8514-buy-game-steam-scarlet-nexus-deluxe/'},
#     {'name': 'Scarlet Nexus Xbox ONE / Xbox Series X|S',
#      'price': '51.89',
#      'discount': 0.26,
#      'platform': 'xbox',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/9085-buy-scarlet-nexus-xbox-one-xbox-series-xs/'}],
#    'best_result': {'name': 'Scarlet Nexus',
#     'price': '32.69',
#     'discount': 0.35,
#     'platform': 'steam',
#     'dlc': False,
#     'link': 'https://www.instant-gaming.com/en/6906-buy-game-steam-scarlet-nexus/'}},
#   'sales_data': None},
#  {'app_id': '287700',
#   'name': 'METAL GEAR SOLID V: THE PHANTOM PAIN',
#   'priority': 6,
#   'price': 29.99,
#   'discount': 0.0,
#   'early_access': False,
#   'prerelease': False,
#   'price_history': [{'time': 1438621203000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1438667102000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1441368002000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1448478483000, 'price': 44.99, 'discount': 0.25},
#    {'time': 1448994098000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1449165933000, 'price': 44.99, 'discount': 0.25},
#    {'time': 1449338731000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1450814363000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1451932990000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1453486445000, 'price': 29.99, 'discount': 0.5},
#    {'time': 1453659128000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1454705847000, 'price': 44.99, 'discount': 0.25},
#    {'time': 1455302063000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1463474799000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1464282643000, 'price': 20.99, 'discount': 0.3},
#    {'time': 1464628299000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1466715851000, 'price': 20.99, 'discount': 0.3},
#    {'time': 1467653983000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1479938083000, 'price': 19.49, 'discount': 0.35},
#    {'time': 1480443047000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1482436840000, 'price': 17.99, 'discount': 0.4},
#    {'time': 1483381900000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1498165377000, 'price': 20.09, 'discount': 0.33},
#    {'time': 1499284078000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1511375638000, 'price': 20.09, 'discount': 0.33},
#    {'time': 1511893591000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1513882306000, 'price': 20.09, 'discount': 0.33},
#    {'time': 1515091272000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1518719080000, 'price': 20.09, 'discount': 0.33},
#    {'time': 1519065171000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1529625782000, 'price': 14.99, 'discount': 0.5},
#    {'time': 1530812381000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1542833876000, 'price': 20.09, 'discount': 0.33},
#    {'time': 1543344235000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1545331342000, 'price': 20.09, 'discount': 0.33},
#    {'time': 1546542320000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1549312507000, 'price': 20.09, 'discount': 0.33},
#    {'time': 1549920917000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1556558687000, 'price': 22.49, 'discount': 0.25},
#    {'time': 1557163324000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1561490298000, 'price': 11.99, 'discount': 0.6},
#    {'time': 1562699607000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1574791765000, 'price': 11.99, 'discount': 0.6},
#    {'time': 1575396759000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1576779075000, 'price': 11.99, 'discount': 0.6},
#    {'time': 1577988883000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1579803140000, 'price': 11.99, 'discount': 0.6},
#    {'time': 1580153071000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1588266358000, 'price': 7.49, 'discount': 0.75},
#    {'time': 1588784919000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1593105211000, 'price': 7.49, 'discount': 0.75},
#    {'time': 1594318997000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1600967172000, 'price': 7.49, 'discount': 0.75},
#    {'time': 1601313847000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1606327708000, 'price': 7.49, 'discount': 0.75},
#    {'time': 1606846846000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1608660861000, 'price': 7.49, 'discount': 0.75},
#    {'time': 1609873341000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1613066902000, 'price': 7.49, 'discount': 0.75},
#    {'time': 1613417667000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1619716230000, 'price': 7.49, 'discount': 0.75},
#    {'time': 1620320767000, 'price': 29.99, 'discount': 0.0},
#    {'time': 1624556029000, 'price': 7.49, 'discount': 0.75},
#    {'time': 1625767104000, 'price': 29.99, 'discount': 0.0}],
#   'ig_data': {'search_results': [{'name': 'Metal Gear Solid V: The Phantom Pain',
#      'price': '3.99',
#      'discount': 0.87,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/488-buy-game-steam-metal-gear-solid-v-the-phantom-pain/'}],
#    'best_result': {'name': 'Metal Gear Solid V: The Phantom Pain',
#     'price': '3.99',
#     'discount': 0.87,
#     'platform': 'steam',
#     'dlc': False,
#     'link': 'https://www.instant-gaming.com/en/488-buy-game-steam-metal-gear-solid-v-the-phantom-pain/'}},
#   'sales_data': {'latest': {'time': 1624556029000,
#     'price': 7.49,
#     'discount': 0.75},
#    'biggest': {'time': 1624556029000, 'price': 7.49, 'discount': 0.75},
#    'same': True}},
#  {'app_id': '1113560',
#   'name': 'NieR Replicant™ ver.1.22474487139...',
#   'priority': 7,
#   'price': 59.99,
#   'discount': 0.0,
#   'early_access': False,
#   'prerelease': False,
#   'price_history': [{'time': 1600963805000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1624562208000, 'price': 44.99, 'discount': 0.25},
#    {'time': 1625774346000, 'price': 59.99, 'discount': 0.0}],
#   'ig_data': {'search_results': [{'name': 'NieR Replicant ver.1.22474487139',
#      'price': '32.99',
#      'discount': 0.45,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/6716-buy-game-steam-nier-replicant-ver122474487139/'},
#     {'name': 'NieR Replicant ver.1.22474487139 Xbox ONE / Xbox Series X|S',
#      'price': '51.99',
#      'discount': 0.13,
#      'platform': 'xbox',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/8694-buy-nier-replicant-ver122474487139-xbox-one-xbox-series-xs/'}],
#    'best_result': {'name': 'NieR Replicant ver.1.22474487139',
#     'price': '32.99',
#     'discount': 0.45,
#     'platform': 'steam',
#     'dlc': False,
#     'link': 'https://www.instant-gaming.com/en/6716-buy-game-steam-nier-replicant-ver122474487139/'}},
#   'sales_data': {'latest': {'time': 1624562208000,
#     'price': 44.99,
#     'discount': 0.25},
#    'biggest': {'time': 1624562208000, 'price': 44.99, 'discount': 0.25},
#    'same': True}},
#  {'app_id': '1113000',
#   'name': 'Persona 4 Golden',
#   'priority': 8,
#   'price': 19.99,
#   'discount': 0.0,
#   'early_access': False,
#   'prerelease': False,
#   'price_history': [{'time': 1592070901000, 'price': 19.99, 'discount': 0.0},
#    {'time': 1602263300000, 'price': 15.99, 'discount': 0.2},
#    {'time': 1603128406000, 'price': 19.99, 'discount': 0.0},
#    {'time': 1606327529000, 'price': 15.99, 'discount': 0.2},
#    {'time': 1606848590000, 'price': 19.99, 'discount': 0.0},
#    {'time': 1608660881000, 'price': 15.99, 'discount': 0.2},
#    {'time': 1609871506000, 'price': 19.99, 'discount': 0.0},
#    {'time': 1613067006000, 'price': 15.99, 'discount': 0.2},
#    {'time': 1613417704000, 'price': 19.99, 'discount': 0.0},
#    {'time': 1619716219000, 'price': 13.99, 'discount': 0.3},
#    {'time': 1620321374000, 'price': 19.99, 'discount': 0.0},
#    {'time': 1624559420000, 'price': 12.99, 'discount': 0.35},
#    {'time': 1625768971000, 'price': 19.99, 'discount': 0.0}],
#   'ig_data': {'search_results': [{'name': 'Persona 4 Golden - Digital Deluxe Edition',
#      'price': '12.99',
#      'discount': 0.35,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/7129-buy-game-steam-persona-4-golden-digital-deluxe-edition/'},
#     {'name': 'Persona 4 Golden',
#      'price': '11.09',
#      'discount': 0.45,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/7088-buy-game-steam-persona-4-golden/'}],
#    'best_result': {'name': 'Persona 4 Golden - Digital Deluxe Edition',
#     'price': '12.99',
#     'discount': 0.35,
#     'platform': 'steam',
#     'dlc': False,
#     'link': 'https://www.instant-gaming.com/en/7129-buy-game-steam-persona-4-golden-digital-deluxe-edition/'}},
#   'sales_data': {'latest': {'time': 1624559420000,
#     'price': 12.99,
#     'discount': 0.35},
#    'biggest': {'time': 1624559420000, 'price': 12.99, 'discount': 0.35},
#    'same': True}},
#  {'app_id': '1382330',
#   'name': 'Persona® 5 Strikers',
#   'priority': 9,
#   'price': 59.99,
#   'discount': 0.0,
#   'early_access': False,
#   'prerelease': False,
#   'price_history': [{'time': 1607644810000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1613703604000, 'price': 69.99, 'discount': 0.0},
#    {'time': 1613705408000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1619716416000, 'price': 52.49, 'discount': 0.25},
#    {'time': 1619717059000, 'price': 47.99, 'discount': 0.2},
#    {'time': 1620321313000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1624558848000, 'price': 40.19, 'discount': 0.33},
#    {'time': 1625767973000, 'price': 59.99, 'discount': 0.0}],
#   'ig_data': {'search_results': [{'name': 'Persona 5 Strikers',
#      'price': '32.99',
#      'discount': 0.45,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/7975-buy-game-steam-persona-5-strikers/'},
#     {'name': 'Persona 5 Strikers - Digital Deluxe Edition',
#      'price': '37.49',
#      'discount': 0.46,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/8301-buy-game-steam-persona-5-strikers-digital-deluxe-edition/'},
#     {'name': 'Persona 5 Scramble Strikers Switch',
#      'price': '0.00',
#      'discount': None,
#      'platform': 'switch',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/6149-buy-game-nintendo-persona-5-scramble-strikers-switch/'}],
#    'best_result': {'name': 'Persona 5 Strikers',
#     'price': '32.99',
#     'discount': 0.45,
#     'platform': 'steam',
#     'dlc': False,
#     'link': 'https://www.instant-gaming.com/en/7975-buy-game-steam-persona-5-strikers/'}},
#   'sales_data': {'latest': {'time': 1624558848000,
#     'price': 40.19,
#     'discount': 0.33},
#    'biggest': {'time': 1624558848000, 'price': 40.19, 'discount': 0.33},
#    'same': True}},
#  {'app_id': '1325200',
#   'name': 'Nioh 2 – The Complete Edition',
#   'priority': 10,
#   'price': 59.99,
#   'discount': 0.0,
#   'early_access': False,
#   'prerelease': False,
#   'price_history': [{'time': 1605276307000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1619111180000, 'price': 47.99, 'discount': 0.2},
#    {'time': 1619458899000, 'price': 59.99, 'discount': 0.0},
#    {'time': 1624556262000, 'price': 47.99, 'discount': 0.2},
#    {'time': 1625768719000, 'price': 59.99, 'discount': 0.0}],
#   'ig_data': {'search_results': [{'name': 'Nioh 2: The Complete Edition',
#      'price': '29.99',
#      'discount': 0.5,
#      'platform': 'steam',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/2716-buy-game-steam-nioh-2-the-complete-edition/'},
#     {'name': 'Nioh 2: The Complete Edition Ps4',
#      'price': '39.99',
#      'discount': 0.33,
#      'platform': 'playstation-4',
#      'dlc': False,
#      'link': 'https://www.instant-gaming.com/en/8195-buy-game-playstation-nioh-2-the-complete-edition-ps4/'}],
#    'best_result': {'name': 'Nioh 2: The Complete Edition',
#     'price': '29.99',
#     'discount': 0.5,
#     'platform': 'steam',
#     'dlc': False,
#     'link': 'https://www.instant-gaming.com/en/2716-buy-game-steam-nioh-2-the-complete-edition/'}},
#   'sales_data': {'latest': {'time': 1624556262000,
#     'price': 47.99,
#     'discount': 0.2},
#    'biggest': {'time': 1624556262000, 'price': 47.99, 'discount': 0.2},
#    'same': True}}]
